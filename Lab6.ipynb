# %%
def selSort(list, len, idx = 0): 
    if idx == len: 
        return ""

    min = min_idx(list, idx, len - 1) 
    if min != idx: 
        list[min], list[idx] = list[idx], list[min]     
    selSort(list, len, idx + 1) 

def min_idx(list, c1, c2): 
    if c1 == c2: 
        return c1
        
    min = min_idx(list, c1 + 1, c2)       
    if list[c1] < list[min]:
        return c1
    else:
        return min 

def print_list (list, c1 = 0):
    if c1 != len(list):
        print (list[c1], end = " ")
        print_list(list, c1 + 1)
    else:
        return ""   

def insSort(list, len):    
    if len <= 1:
        return ""
        
    max = list[len - 1]
    c = len - 2
    insSort(list, len - 1)   
    max_idx (list, c, max)

def max_idx (list, c, max): 
    if list[c] > max and c >= 0:
        list[c + 1] = list[c]
        max_idx (list, c - 1, max)
    else:
        list[c + 1] = max

def print_list (list, c = 0):
    if c != len(list):
        print (list[c], end = " ")
        print_list(list, c + 1)
    else:
        return ""      

  


    
class Node:
    def __init__(self, value = None, next = None):
        self.value = value
        self.next = next

class LinkedList:
    def __init__(self, head = None):
        self.head = head
        
    def printList(self):
        out = ""
        node1 = self.head
        while True:
            if node1.next == None:
                out = out[:-4]
                break  
            out += str(node1.value) + " --> "
            node1 = node1.next
        print(out+"--> "+ str(node1.value))

    def append(self, value = None):
        newNode = Node(value)
        newNode.next = self.head
        self.head = newNode
    
    def bubblesort(self): 
        head1 = self.head          
        while True:
            if head1.next == None:
                break
            head2 = self.head            
            while True:
                if head2.next == None: 
                    break
                if head2.value > head2.next.value: 
                    temp = head2.next.value
                    head2.next.value = head2.value
                    head2.value = temp
                head2 = head2.next 
            head1 = head1.next 


            
            
            
class Node:
    def __init__(self, value = None, next = None):
        self.value = value
        self.next = next

class LinkedList:
    def __init__(self, head = None):
        self.head = head
        
    def printList(self):
        out = ""
        node1 = self.head
        while True:
            if node1.next == None:
                out = out[:-4]
                break  
            out += str(node1.value) + " --> "
            node1 = node1.next
        print(out+"--> "+ str(node1.value))

    def append(self, value = None):
        newNode = Node(value)
        newNode.next = self.head
        self.head = newNode
    
    def selSort(self):        
        head1 = self.head 
        while True:
            if head1.next == None:
                break 
            min = head1 
            head2 = head1.next
            while True:
                if head2 == None:
                    break 
                if min.value > head2.value: 
                    min = head2 
                head2 = head2.next
            temp = head1.value 
            head1.value = min.value 
            min.value = temp 
            head1 = head1.next
         

  

    


class Node:
    def __init__(self, value = None, next = None, prev = None):
        self.value = value
        self.next = next
        self.prev = prev

class DoublyLinkedList:
    def __init__(self, head = None):
        self.head = head

    def append(self, value = None):
        if self.head == None:
            newNode = Node(value)
            newNode.prev = None
            self.head = newNode
        else:
            newNode = Node(value)
            node1 = self.head
            while node1.next:
                node1 = node1.next
            node1.next = newNode
            newNode.prev = node1
            newNode.next = None
        
    def printList(self):
        out = ""
        node1 = self.head
        while True:
            if node1.next == None:
                out = out[:-4]
                break  
            out += str(node1.value) + " --> "
            node1 = node1.next
        print(out+"--> "+ str(node1.value))
    
    def insSort(self):
        head1 = self.head.next
        while True:
            if head1 == None:
                break
            head2 = head1
            temp = head1.value
            while True:
                if head2.prev == None or head2.prev.value < temp:
                    break
                head2.value = head2.prev.value
                head2 = head2.prev
            head2.value = temp
            head1 = head1.next
          

        

def binarySearch(list, start, end, value):
    if start > end:
        return "not found!"
    else:
        mid = int((start + end) / 2)
        if value > list[mid]:
            return binarySearch(list, mid + 1, end, value)
        elif value == list[mid]:
            return mid
        else:
            return binarySearch(list, start, mid - 1, value)




class Memoize:
    def __init__(self, value):
        self.value = value
        self.memoize = {}
    def __call__(self, *args):
        if not args in self.memoize:
            self.memoize[args] = self.value(*args)
        return self.memoize[args]
def fibonacci(n):
    if n == 1 :
        return 0
    
    elif n == 2:
        return 1
    
    else :
        return fibonacci(n - 1) + fibonacci(n - 2)
